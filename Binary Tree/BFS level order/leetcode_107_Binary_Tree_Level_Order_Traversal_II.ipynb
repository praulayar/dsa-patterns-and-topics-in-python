# %% [markdown]
# <a href="https://colab.research.google.com/github/praulayar/dsa-patterns-and-topics-in-python/blob/main/leetcode_107_Binary_Tree_Level_Order_Traversal_II.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [leetcode 107. Binary Tree Level Order Traversal II](https://leetcode.com/problems/binary-tree-level-order-traversal-ii/description/)

# %%
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

# %%
class Solution:
    def levelOrderBottom(self, root: Optional[TreeNode]) -> List[List[int]]:
        if root is None:
            return []

        q = deque([root])
        result = []

        while q:
            size = len(q)
            nodes = []

            for _ in range(size):
                node = q.popleft()
                nodes.append(node.val)

                if node.left:
                    q.append(node.left)

                if node.right:
                    q.append(node.right)

            result.append(nodes)

        return list(reversed(result))
