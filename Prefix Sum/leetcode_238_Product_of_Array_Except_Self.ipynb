# %%
from typing import List

# %% [markdown]
# [leetcode 238. Product of Array Except Self](https://leetcode.com/problems/product-of-array-except-self/description/)

# %%
class Solution:
    def productExceptSelf(self, nums: List[int]) -> List[int]:
        n = len(nums)
        result = [1] * n
        prefix_prod = 1

        for i in range(n):
            suffix_prod = 1
            for j in range(i+1, n):
                suffix_prod *= nums[j]

            result[i] = prefix_prod * suffix_prod
            prefix_prod *= nums[i]

        return result

# %%
class Solution:
    def productExceptSelf(self, nums: List[int]) -> List[int]:
        n = len(nums)
        result = [1] * n

        for i in range(1, n):
            result[i] = result[i-1] * nums[i-1]

        suffix_prod = nums[-1]
        for j in range(n-2, -1, -1):
            result[j] *= suffix_prod
            suffix_prod *= nums[j]

        return result
